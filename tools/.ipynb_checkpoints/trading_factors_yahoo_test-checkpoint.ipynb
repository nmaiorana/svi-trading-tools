# %%
import unittest
import pandas as pd

# %% [markdown]
# # Test Harness

# %%
import pandas_datareader as pdr
from datetime import datetime

start = datetime(year=2019, month=1, day=1)
end = datetime(year=2020, month=1, day=1)

yahoo_reader = pdr.yahoo.daily.YahooDailyReader(symbols=['AAPL', 'GOOG'], start=start, end=end, adjust_price=True, interval='d', get_actions=False, adjust_dividends=True)
test_data_df = yahoo_reader.read()
yahoo_reader.close()

# %%
test_data_df.head()
# Out:
# Attributes Adj_Ratio           Close                    High               \
# Symbols         AAPL GOOG       AAPL         GOOG       AAPL         GOOG
# Date
# 2019-01-02  0.969542  1.0  38.277523  1045.849976  38.502944  1052.319946
# 2019-01-03  0.969542  1.0  34.464802  1016.059998  35.320422  1056.979980
# 2019-01-04  0.969542  1.0  35.936077  1070.709961  36.006371  1070.839966
# 2019-01-07  0.969542  1.0  35.856094  1068.390015  36.074244  1074.000000
# 2019-01-08  0.969542  1.0  36.539623  1076.280029  36.798978  1084.560059
#
# Attributes        Low                    Open                    Volume  \
# Symbols          AAPL         GOOG       AAPL         GOOG         AAPL
# Date
# 2019-01-02  37.383120  1015.710022  37.543095  1016.570007  148158800.0
# 2019-01-03  34.418748  1014.070007  34.898670  1041.000000  365248800.0
# 2019-01-04  34.855040  1027.417969  35.031980  1032.589966  234428400.0
# 2019-01-07  35.364052  1054.760010  36.042732  1071.500000  219111200.0
# 2019-01-08  35.999104  1060.530029  36.251184  1076.109985  164101200.0
#
# Attributes
# Symbols          GOOG
# Date
# 2019-01-02  1532600.0
# 2019-01-03  1841100.0
# 2019-01-04  2093900.0
# 2019-01-07  1981900.0
# 2019-01-08  1764900.0

# %%
test_data_df['Close'].head()
# Out:
# Symbols          AAPL         GOOG
# Date
# 2019-01-02  38.277523  1045.849976
# 2019-01-03  34.464802  1016.059998
# 2019-01-04  35.936077  1070.709961
# 2019-01-07  35.856094  1068.390015
# 2019-01-08  36.539623  1076.280029

# %%
test_data_df['Close'].tail()
# Out:
# Symbols          AAPL         GOOG
# Date
# 2019-12-24  69.938202  1343.560059
# 2019-12-26  71.325798  1360.400024
# 2019-12-27  71.298737  1351.890015
# 2019-12-30  71.721909  1336.140015
# 2019-12-31  72.245934  1337.020020

# %% [markdown]
# # Unit Tests

# %%
import importlib
import trading_factors_yahoo as alpha_factors
importlib.reload(alpha_factors)

class TestFactorData(unittest.TestCase):
    def test_init(self):
        class_under_test = alpha_factors.FactorData(test_data_df)
        self.assertEqual(class_under_test.factor_name, 'Alpha Factor')
        self.assertEqual(class_under_test.factor_data.columns, factor_data_df.columns)
        
    def test_rank(self):
        class_under_test = alpha_factors.FactorData(test_data_df)
        self.assertFalse(True)
    
    def test_demean(self):
        self.assertFalse(True)
        
    def test_zscore(self):
        self.assertFalse(True)
        
    def test_smoothed(self):
        self.assertFalse(True)
        
    def test_for_al(self):
        self.assertFalse(True)
        
    def test_close_values(self):
        class_under_test = alpha_factors.ClosePrices(test_data_df)
        self.assertEqual(class_under_test.factor_data.columns[0], 'AAPL')
        self.assertAlmostEqual(class_under_test.factor_data.loc['2019-01-02']['AAPL'], 38.277523, places=4)
        self.assertAlmostEqual(class_under_test.factor_data.loc['2019-12-31']['AAPL'], 72.245934, places=4)

# %%
TestFactorData().test_close_values()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\ml4t\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Open'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-a1d392d5ae14> in <module>
# ----> 1 TestFactorData().test_close_values()
#
# <ipython-input-61-900cc9fa1ec7> in test_close_values(self)
#      27     def test_close_values(self):
#      28         class_under_test = alpha_factors.ClosePrices(test_data_df)
# ---> 29         close_values = class_under_test.get_close_values()
#      30         self.assertEqual(class_under_test.factor_data.columns[0], 'AAPL')
#      31         self.assertAlmostEqual(class_under_test.factor_data.loc['2019-01-02']['AAPL'], 38.277523, places=4)
#
# ~\Anaconda Projects\svi-trading-tools\tools\trading_factors_yahoo.py in get_close_values(self)
#      61
#      62     def get_close_values(self):
# ---> 63         open_values = self.factor_data[self.open_col]
#      64         close_values = self.factor_data[self.close_col]
#      65         close_values = close_values.fillna(open_values.ffill())
#
# ~\anaconda3\envs\ml4t\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\envs\ml4t\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Open'

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_close_values (__main__.TestFactorData) ... ERROR
# test_demean (__main__.TestFactorData) ... FAIL
# test_for_al (__main__.TestFactorData) ... FAIL
# test_init (__main__.TestFactorData) ... ERROR
# test_rank (__main__.TestFactorData) ... FAIL
# test_smoothed (__main__.TestFactorData) ... FAIL
# test_zscore (__main__.TestFactorData) ... FAIL
#
# ======================================================================
# ERROR: test_close_values (__main__.TestFactorData)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-26-1ed858a360ee>", line 31, in test_close_values
#     class_under_test.get_close_values()
#   File "C:\Users\HP-Z440\Anaconda Projects\svi-trading-tools\tools\trading_factors.py", line 63, in get_close_values
#     open_values = get_values_by_date(price_histories_df, self.open_col)
# NameError: name 'get_values_by_date' is not defined
#
# ======================================================================
# ERROR: test_init (__main__.TestFactorData)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-26-1ed858a360ee>", line 9, in test_init
#     self.assertEqual(class_under_test.factor_data.columns, factor_data_df.columns)
#   File "C:\Users\HP-Z440\anaconda3\envs\ml4t\lib\unittest\case.py", line 912, in assertEqual
#     assertion_func(first, second, msg=msg)
#   File "C:\Users\HP-Z440\anaconda3\envs\ml4t\lib\unittest\case.py", line 902, in _baseAssertEqual
#     if not first == second:
#   File "C:\Users\HP-Z440\anaconda3\envs\ml4t\lib\site-packages\pandas\core\ops\common.py", line 65, in new_method
#     return method(self, other)
#   File "C:\Users\HP-Z440\anaconda3\envs\ml4t\lib\site-packages\pandas\core\arraylike.py", line 29, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "C:\Users\HP-Z440\anaconda3\envs\ml4t\lib\site-packages\pandas\core\indexes\base.py", line 5615, in _cmp_method
#     raise ValueError("Lengths must match to compare")
# ValueError: Lengths must match to compare
#
# ======================================================================
# FAIL: test_demean (__main__.TestFactorData)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-26-1ed858a360ee>", line 16, in test_demean
#     self.assertFalse(True)
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_for_al (__main__.TestFactorData)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-26-1ed858a360ee>", line 25, in test_for_al
#     self.assertFalse(True)
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_rank (__main__.TestFactorData)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-26-1ed858a360ee>", line 13, in test_rank
#     self.assertFalse(True)
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_smoothed (__main__.TestFactorData)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-26-1ed858a360ee>", line 22, in test_smoothed
#     self.assertFalse(True)
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_zscore (__main__.TestFactorData)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-26-1ed858a360ee>", line 19, in test_zscore
#     self.assertFalse(True)
# AssertionError: True is not false
#
# ----------------------------------------------------------------------
# Ran 7 tests in 0.016s
#
# FAILED (failures=5, errors=2)
