# %%
from pathlib import Path

parquet_file_path = Path('filename.parquet')

print(parquet_file_path.suffix)

# %%
import tools.price_histories_helper as phh
price_histories_path = Path('../data/price_histories_yahoo.parquet')
price_histories_df = phh.load_price_histories(price_histories_path)
display(price_histories_df.describe())
# Out:
# Attributes        Close                                                      \
# Symbols               A          AAL          AAP         AAPL         ABBV
# count       1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean         105.517593    22.481541   158.124623   103.286648    98.448094
# std           33.668999     9.106484    30.370953    46.086408    31.885207
# min           58.910000     9.040000    70.080000    34.260000    53.030000
# 25%           73.470000    14.420000   140.690000    52.600000    73.220000
# 50%          103.730000    19.760000   150.310000   115.550000    86.370000
# 75%          134.065000    30.180000   179.575000   145.555000   128.955000
# max          177.360000    45.580000   230.370000   180.680000   167.010000
#
# Attributes                                                                   \
# Symbols             ABC          ABT         ACGL          ACN         ADBE
# ...

# %%
price_histories_df.sample(10)
# Out:
# Attributes   Close                                                        \
# Symbols          A    AAL     AAP    AAPL    ABBV     ABC     ABT   ACGL
# Date
# 2019-03-26   78.25  29.81  156.56   45.20   66.10   71.89   73.74  31.96
# 2020-02-13   83.64  30.09  125.44   79.63   82.55   90.45   84.11  47.83
# 2020-12-01  113.62  14.27  143.02  121.08   93.79   99.10  104.08  33.02
# 2019-06-25   70.50  30.94  143.80   47.50   54.48   79.55   78.95  35.91
# 2020-07-24   93.21  11.39  137.80   91.06   86.37   99.79   94.61  30.85
# 2019-08-05   64.17  28.23  133.25   46.96   54.92   83.73   78.23  37.76
# 2020-03-10   71.35  17.00  125.93   69.94   75.78   82.37   76.71  37.83
# 2020-11-24  112.95  14.82  140.42  113.63   93.72   99.98  103.24  34.55
# 2021-05-18  127.21  23.56  188.02  123.57  108.20  114.30  113.09  40.17
# 2019-05-13   71.79  31.81  144.55   45.11   63.75   71.07   70.76  33.32
#
# Attributes                  ...   Volume                                       \
# ...
