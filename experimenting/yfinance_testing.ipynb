# %%
import pandas as pd
import tools.trading_factors_yahoo as tf
import tools.utils as utils
import yfinance as yf

print(f'yfiance: {yf.__version__}')
# Out:
# yfiance: 0.2.18

# %%
test_data_df = pd.read_csv('./tools/tests/test_data/test_data.csv', header=[0, 1], index_col=[0], parse_dates=True, low_memory=False)

test_data_df
# Out:
# Attributes Adj_Ratio           Close                    High               \
# Symbols         AAPL GOOG       AAPL         GOOG       AAPL         GOOG
# Date
# 2019-01-02  0.968120  1.0  38.221363  1045.849976  38.446453  1052.319946
# 2019-01-03  0.968120  1.0  34.414234  1016.059998  35.268599  1056.979980
# 2019-01-04  0.968120  1.0  35.883362  1070.709961  35.953553  1070.839966
# 2019-01-07  0.968120  1.0  35.803493  1068.390015  36.021323  1074.000000
# 2019-01-08  0.968120  1.0  36.486012  1076.280029  36.744985  1084.560059
# ...              ...  ...        ...          ...        ...          ...
# 2019-12-24  0.982666  1.0  69.835602  1343.560059  69.987921  1350.260010
# 2019-12-26  0.982666  1.0  71.221161  1360.400024  71.238359  1361.327026
# 2019-12-27  0.982666  1.0  71.194122  1351.890015  72.218555  1364.530029
# 2019-12-30  0.982666  1.0  71.616692  1336.140015  71.904125  1353.000000
# 2019-12-31  0.982666  1.0  72.139938  1337.020020  72.147308  1338.000000
#
# ...

# %%
returns = tf.FactorReturns(test_data_df).factor_data
returns
# Out:
# Symbols         AAPL      GOOG
# Date
# 2019-01-02       NaN       NaN
# 2019-01-03 -0.099607 -0.028484
# 2019-01-04  0.042690  0.053786
# 2019-01-07 -0.002226 -0.002167
# 2019-01-08  0.019063  0.007385
# ...              ...       ...
# 2019-12-24  0.000951 -0.003914
# 2019-12-26  0.019840  0.012534
# 2019-12-27 -0.000380 -0.006256
# 2019-12-30  0.005935 -0.011650
# 2019-12-31  0.007306  0.000659
#
# [252 rows x 2 columns]

# %%
pd.qcut(returns, False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 pd.qcut(returns, False)
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\pandas\core\reshape\tile.py:370, in qcut(x, q, labels, retbins, precision, duplicates)
#     316 """
#     317 Quantile-based discretization function.
#     318
#    (...)
#     367 array([0, 0, 1, 2, 3])
#     368 """
#     369 original = x
# --> 370 x = _preprocess_for_cut(x)
#     371 x, dtype = _coerce_to_type(x)
#     373 quantiles = np.linspace(0, 1, q + 1) if is_integer(q) else q
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\pandas\core\reshape\tile.py:602, in _preprocess_for_cut(x)
#     600     x = np.asarray(x)
#     601 if x.ndim != 1:
# --> 602     raise ValueError("Input array must be 1 dimensional")
#     604 return x
#
# ValueError: Input array must be 1 dimensional

# %%
# Get the list of S&P 500 tickers
tickers = yf.Tickers('^GSPC')
tickers.
# Out:
# {'^GSPC': yfinance.Ticker object <^GSPC>}

# %%
tickers = utils.get_snp500().index.to_list()

# %%
fundamentals = {}
for ticker in tickers:
    fundamentals[ticker] = yf.Ticker(ticker).financials(period='5y')

# Print the fundamentals data
for ticker, data in fundamentals.items():
    print(ticker, data['total_revenue'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 fundamentals = {}
#       2 for ticker in tickers:
# ----> 3     fundamentals[ticker] = yf.Ticker(ticker).financials(period='5y')
#       5 # Print the fundamentals data
#       6 for ticker, data in fundamentals.items():
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\yfinance\ticker.py:174, in Ticker.financials(self)
#     172 @property
#     173 def financials(self) -> _pd.DataFrame:
# --> 174     return self.income_stmt
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\yfinance\ticker.py:158, in Ticker.income_stmt(self)
#     156 @property
#     157 def income_stmt(self) -> _pd.DataFrame:
# --> 158     return self.get_income_stmt(pretty=True)
#
# ...

# %%
yf.Ticker('AAPL').info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 yf.Ticker('AAPL').info()
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\yfinance\ticker.py:138, in Ticker.info(self)
#     136 @property
#     137 def info(self) -> dict:
# --> 138     return self.get_info()
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\yfinance\base.py:894, in TickerBase.get_info(self, proxy)
#     892 def get_info(self, proxy=None) -> dict:
#     893     self._quote.proxy = proxy
# --> 894     data = self._quote.info
#     895     return data
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\yfinance\scrapers\quote.py:27, in Quote.info(self)
#      24 @property
#      25 def info(self) -> dict:
#      26     if self._info is None:
# ---> 27         self._scrape(self.proxy)
#      28         self._scrape_complementary(self.proxy)
# ...

# %%
import yfinance as yf

# Define the ticker symbol
ticker = '^GSPC'

# Use yfinance to download the data
data = yf.Ticker(ticker)

# Get the fundamentals data for the last 5 years
fundamentals = data.quarterly_financials.T.tail(20)

print(fundamentals)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7 data = yf.Ticker(ticker)
#       9 # Get the fundamentals data for the last 5 years
# ---> 10 fundamentals = data.quarterly_financials.T.tail(20)
#      12 print(fundamentals)
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\yfinance\ticker.py:178, in Ticker.quarterly_financials(self)
#     176 @property
#     177 def quarterly_financials(self) -> _pd.DataFrame:
# --> 178     return self.quarterly_income_stmt
#
# File ~\anaconda3\envs\svi_tt_p308\lib\site-packages\yfinance\ticker.py:162, in Ticker.quarterly_income_stmt(self)
#     160 @property
#     161 def quarterly_income_stmt(self) -> _pd.DataFrame:
# --> 162     return self.get_income_stmt(pretty=True, freq='quarterly')
#
# ...
